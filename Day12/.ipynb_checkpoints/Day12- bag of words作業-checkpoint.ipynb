# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
import re
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    #tokenized_sentence = [x.replace(" ", "") for x in re.split(r'([^a-zA-Z\']+)', sentence) if (x != "" and x != " ")] #'使用tokenize 技巧'
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
#whole_words = {word for word in whole_words}
whole_words = set(whole_words)

# %% [markdown]
# ### 移除重複單字

# %%
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""
    index_word[n] = word
    word_index[word] = n
    n += 1

# %%
word_index
# Out:
# {'serivce': 0,
#  'mussels': 1,
#  'sweet': 2,
#  'fan': 3,
#  'grilled': 4,
#  'couple': 5,
#  'heat': 6,
#  'charged': 7,
#  "ya'all": 8,
#  'ago': 9,
#  'Good': 10,
#  'care': 11,
#  'sandwiches': 12,
#  'world': 13,
#  'mostly': 14,
#  'worries': 15,
#  'Your': 16,
#  'veal': 17,
#  'close': 18,
#  'charge': 19,
#  'frustrated': 20,
#  'Philadelphia': 21,
#  'Mmmm': 22,
#  'light': 23,
#  'soup': 24,
#  'else': 25,
#  'personally': 26,
#  'least': 27,
#  'hostess': 28,
#  'Despite': 29,
#  "'s": 30,
#  'profound': 31,
#  'Ryan': 32,
#  'wagyu': 33,
#  'Weird': 34,
#  'serve': 35,
#  'at': 36,
#  'lovely': 37,
#  'Although': 38,
#  'forty': 39,
#  'truffle': 40,
#  'fav': 41,
#  'atrocious': 42,
#  'glass': 43,
#  'twice': 44,
#  'delish': 45,
#  'craving': 46,
#  'fried': 47,
#  'brick': 48,
#  'register': 49,
#  'doing': 50,
#  'sushi': 51,
#  'felt': 52,
#  'theft': 53,
#  'worth': 54,
#  'honest': 55,
#  'sugary': 56,
#  'strangers': 57,
#  'been': 58,
#  'suck': 59,
#  'changing': 60,
#  'pats': 61,
#  'decide': 62,
#  'color': 63,
#  'metro': 64,
#  'Tucson': 65,
#  'hardest': 66,
#  'decorated': 67,
#  'spinach': 68,
#  'Burger': 69,
#  'with': 70,
#  'wildly': 71,
#  'drenched': 72,
#  'reviewing': 73,
#  'places': 74,
#  'Must': 75,
#  'flavourful': 76,
#  'topic': 77,
#  'gyro': 78,
#  'chefs': 79,
#  'happy': 80,
#  ':': 81,
#  'pizza': 82,
#  'jewel': 83,
#  'tasty': 84,
#  'disgust': 85,
#  'NO': 86,
#  'say': 87,
#  'Gordon': 88,
#  'beautiful': 89,
#  'tacos': 90,
#  'My': 91,
#  'Kind': 92,
#  'funny': 93,
#  'dessert': 94,
#  'missed': 95,
#  'ourselves': 96,
#  'thick': 97,
#  'readers': 98,
#  'Sadly': 99,
#  'manager': 100,
#  'tea': 101,
#  'sugar': 102,
#  'head': 103,
#  'Fantastic': 104,
#  'parents': 105,
#  'quit': 106,
#  'further': 107,
#  'Gold': 108,
#  'bites': 109,
#  'vegetables': 110,
#  'slaw': 111,
#  'stepped': 112,
#  'spicier': 113,
#  'bellies': 114,
#  'accident': 115,
#  'though': 116,
#  'giving': 117,
#  'vomited': 118,
#  'smooth': 119,
#  'Probably': 120,
#  'Tasty': 121,
#  'Perfect': 122,
#  'approval': 123,
#  'batter': 124,
#  'fat': 125,
#  'life': 126,
#  'attached': 127,
#  'exceptional': 128,
#  'Why': 129,
#  'worst': 130,
#  'crepe': 131,
#  'seems': 132,
#  'Gyros': 133,
#  'done': 134,
#  'correction': 135,
#  'Ha': 136,
#  'cheated': 137,
#  'holiday': 138,
#  'arrives': 139,
#  'delivery': 140,
#  'Chipotle': 141,
#  'describing': 142,
#  'These': 143,
#  'occasions': 144,
#  'gloves.Everything': 145,
#  'flirting': 146,
#  'unwelcome': 147,
#  "'m": 148,
#  'wave': 149,
#  'dreamed': 150,
#  'prime': 151,
#  'Mushroom': 152,
#  'indicate': 153,
#  'Bisque': 154,
#  'large': 155,
#  'calamari': 156,
#  'polite': 157,
#  'promise': 158,
#  'reasonable': 159,
#  'Food': 160,
#  'actual': 161,
#  'exactly': 162,
#  'caterpillar': 163,
#  'eyed': 164,
#  'beauty': 165,
#  'feel': 166,
#  'be': 167,
#  'rice': 168,
#  'similar': 169,
#  '4.00': 170,
#  'she': 171,
#  'Chinese': 172,
#  'OMG': 173,
#  'outta': 174,
#  '.': 175,
#  'visited': 176,
#  'known': 177,
#  'plain': 178,
#  'Jenni': 179,
#  'Aria': 180,
#  'yummy': 181,
#  'no': 182,
#  'or': 183,
#  'bye': 184,
#  'Hunan': 185,
#  'tastings': 186,
#  'about': 187,
#  '90': 188,
#  'during': 189,
#  'caring': 190,
#  'ahead': 191,
#  'She': 192,
#  'returned': 193,
#  'combo': 194,
#  'horrible': 195,
#  'effort': 196,
#  'Furthermore': 197,
#  'above': 198,
#  'workers': 199,
#  'plantains': 200,
#  'arepas': 201,
#  'platter': 202,
#  'number': 203,
#  'myself': 204,
#  'patty': 205,
#  'Those': 206,
#  'vinaigrette': 207,
#  'AN': 208,
#  'rib': 209,
#  'Owner': 210,
#  'recently': 211,
#  'charcoal': 212,
#  'juice': 213,
#  'tummy': 214,
#  'fluffy': 215,
#  'swung': 216,
#  'returning': 217,
#  'Great': 218,
#  'order': 219,
#  'strip': 220,
#  'experience': 221,
#  'puree': 222,
#  'missing': 223,
#  'Pho': 224,
#  'Do': 225,
#  'will': 226,
#  'ALL': 227,
#  'APPETIZERS': 228,
#  'sound': 229,
#  'Scottsdale': 230,
#  'business': 231,
#  'solid': 232,
#  'papers': 233,
#  'Francisco': 234,
#  'creamy': 235,
#  'Standard': 236,
#  'doubt': 237,
#  'grill': 238,
#  'Customer': 239,
#  'Much': 240,
#  'without': 241,
#  'spices': 242,
#  'wrap': 243,
#  'nasty': 244,
#  'lovers': 245,
#  'dog': 246,
#  'Really': 247,
#  'accomodate': 248,
#  'tender': 249,
#  'original': 250,
#  'pace': 251,
#  'replenished': 252,
#  '3/4ths': 253,
#  'Chicken': 254,
#  'Third': 255,
#  'would': 256,
#  'definately': 257,
#  'cover': 258,
#  'always': 259,
#  '%': 260,
#  'Mary': 261,
#  'front': 262,
#  'want': 263,
#  'Are': 264,
#  'arrived': 265,
#  'lettuce': 266,
#  'together': 267,
#  'not': 268,
#  'crazy': 269,
#  'suggestions': 270,
#  'genuinely': 271,
#  'relleno': 272,
#  'chipolte': 273,
#  'MUST': 274,
#  'read': 275,
#  'somewhat': 276,
#  'girlfriend': 277,
#  'memory': 278,
#  'have': 279,
#  'soundtrack': 280,
#  'cakes': 281,
#  'cute': 282,
#  'asked': 283,
#  'Thumbs': 284,
#  'oil': 285,
#  'pretty': 286,
#  'Steve': 287,
#  'most': 288,
#  'Anyway': 289,
#  'treat': 290,
#  'After': 291,
#  'are': 292,
#  'inspired': 293,
#  'itself': 294,
#  'Pizza': 295,
#  '``': 296,
#  'dining': 297,
#  'Attack': 298,
#  'eaten': 299,
#  'down': 300,
#  'glance': 301,
#  'driving': 302,
#  'haunt': 303,
#  'dirty-': 304,
#  'grossed': 305,
#  'pears': 306,
#  'Nan': 307,
#  'satisfying': 308,
#  'Hopefully': 309,
#  'curry': 310,
#  'final': 311,
#  'ways': 312,
#  'Pineapple': 313,
#  'know': 314,
#  'famous': 315,
#  'lawyers': 316,
#  'Wow': 317,
#  'so': 318,
#  'Area': 319,
#  'do': 320,
#  'charming': 321,
#  'dedicated': 322,
#  'use': 323,
#  'sat': 324,
#  'fireball': 325,
#  'NOW': 326,
#  'nut': 327,
#  'fish': 328,
#  'professional': 329,
#  'poisoning': 330,
#  'Favorite': 331,
#  'than': 332,
#  'mozzarella': 333,
#  'imagine': 334,
#  'sitting': 335,
#  'AVOID': 336,
#  'In': 337,
#  'screwed': 338,
#  'UNREAL': 339,
#  'bucks': 340,
#  'whatsoever': 341,
#  'him': 342,
#  'quantity': 343,
#  'we': 344,
#  'last': 345,
#  'taco': 346,
#  'Paradise': 347,
#  'Disappointed': 348,
#  'FORWARD': 349,
#  'dirty': 350,
#  'fillet': 351,
#  'angry': 352,
#  'refried': 353,
#  'Eggplant': 354,
#  'muffin': 355,
#  'rge': 356,
#  'friendly': 357,
#  'still': 358,
#  'box': 359,
#  'nay': 360,
#  'starving': 361,
#  'appealing': 362,
#  'he': 363,
#  'EXPERIENCE': 364,
#  'pancakes': 365,
#  'par': 366,
#  'dirt': 367,
#  'besides': 368,
#  'fill': 369,
#  'they': 370,
#  'waitresses': 371,
#  'Cotta': 372,
#  'Google': 373,
#  'working/eating': 374,
#  'overhaul': 375,
#  'fucking': 376,
#  'chai': 377,
#  'basically': 378,
#  'Greek': 379,
#  'Dessert': 380,
#  'boys': 381,
#  'Tigerlilly': 382,
#  'mood': 383,
#  'crab': 384,
#  'used': 385,
#  'downside': 386,
#  'ratio': 387,
#  'fast': 388,
#  'gave': 389,
#  'insanely': 390,
#  'correct': 391,
#  'server': 392,
#  'almonds': 393,
#  'location': 394,
#  'sever': 395,
#  'Breeze': 396,
#  'NYC': 397,
#  'short': 398,
#  'constructed': 399,
#  'chip': 400,
#  'take': 401,
#  'Would': 402,
#  'flavor': 403,
#  'Everything': 404,
#  'duck': 405,
#  'building': 406,
#  'Crema': 407,
#  'spends': 408,
#  'Best': 409,
#  'greeted': 410,
#  'Del': 411,
#  'smelled': 412,
#  'getting': 413,
#  'how': 414,
#  'Firehouse': 415,
#  'Delicious': 416,
#  'exceeding': 417,
#  'towards': 418,
#  'couples': 419,
#  'pine': 420,
#  'mistake': 421,
#  'connoisseur': 422,
#  'spicy': 423,
#  'BEST': 424,
#  'What': 425,
#  'raspberry': 426,
#  'Hell': 427,
#  'tap': 428,
#  'wait': 429,
#  'covered': 430,
#  'smoothies': 431,
#  'Boy': 432,
#  'BITCHES': 433,
#  'her': 434,
#  'gratuity': 435,
#  'ethic': 436,
#  'onion': 437,
#  'FLAVOR': 438,
#  'cake': 439,
#  'portion': 440,
#  'regularly': 441,
#  'hooked': 442,
#  'caught': 443,
#  'flavorless': 444,
#  'coconut': 445,
#  'Jeff': 446,
#  'airport': 447,
#  'thought': 448,
#  'mein': 449,
#  '8': 450,
#  'callings': 451,
#  '*': 452,
#  'Ninja': 453,
#  'black': 454,
#  'due': 455,
#  'lukewarm': 456,
#  'boxes': 457,
#  'huge': 458,
#  'pleasure': 459,
#  'obviously': 460,
#  'drag': 461,
#  'elegantly': 462,
#  'Shrimp-': 463,
#  'average': 464,
#  'banana': 465,
#  'star': 466,
#  'ala': 467,
#  'turn': 468,
#  'boyfriend': 469,
#  'THE': 470,
#  'falling': 471,
#  'pastry': 472,
#  'struggle': 473,
#  'biscuits': 474,
#  'apologize': 475,
#  'guacamole': 476,
#  'SHOULD': 477,
#  'rave': 478,
#  'cost': 479,
#  'barely': 480,
#  'family': 481,
#  'fail': 482,
#  'owned': 483,
#  'Host': 484,
#  'Bellagio': 485,
#  'bowl': 486,
#  'cream': 487,
#  'Of': 488,
#  'Mediocre': 489,
#  'hilarious': 490,
#  'profiterole': 491,
#  '40': 492,
#  '1': 493,
#  'fabulous': 494,
#  'cafe': 495,
#  'thinking': 496,
#  'TOLD': 497,
#  'enjoyable': 498,
#  'terrible': 499,
#  'restaurant': 500,
#  'sign': 501,
#  'drastically': 502,
#  'petty': 503,
#  'gone': 504,
#  'weekend': 505,
#  'end': 506,
#  'selection': 507,
#  'in': 508,
#  'pack': 509,
#  'spot': 510,
#  'allergy': 511,
#  'winner': 512,
#  'crawfish': 513,
#  'lightly': 514,
#  'find': 515,
#  'Heart': 516,
#  'Penne': 517,
#  'Caesar': 518,
#  'mixed': 519,
#  'writing': 520,
#  'older': 521,
#  'crêpe': 522,
#  'enthusiastic': 523,
#  'vanilla': 524,
#  'pissd': 525,
#  'killer': 526,
#  'hard': 527,
#  'apology': 528,
#  'ordering': 529,
#  'loved': 530,
#  'on': 531,
#  'shopping': 532,
#  'helped': 533,
#  'pancake': 534,
#  'particular': 535,
#  'gluten': 536,
#  'dry': 537,
#  'goat': 538,
#  'unhealthy': 539,
#  'ignore': 540,
#  'can': 541,
#  'top': 542,
#  'apart': 543,
#  'hand': 544,
#  'over': 545,
#  'pleasant': 546,
#  'Grill': 547,
#  'opinion': 548,
#  'However': 549,
#  'Tasted': 550,
#  'sauce': 551,
#  'pastas': 552,
#  'kiddos': 553,
#  'Mom': 554,
#  'juries': 555,
#  '--': 556,
#  'pepper': 557,
#  'mushrooms': 558,
#  '&': 559,
#  'healthy': 560,
#  'Check': 561,
#  'yellow': 562,
#  'lots': 563,
#  'unbelievable': 564,
#  'mom': 565,
#  'signs': 566,
#  'realized': 567,
#  'of': 568,
#  'ribeye': 569,
#  'figured': 570,
#  'offers': 571,
#  'BARGAIN': 572,
#  'witnessed': 573,
#  'sticks': 574,
#  'patron': 575,
#  'extensive': 576,
#  '23': 577,
#  'baby': 578,
#  'added': 579,
#  'Filet': 580,
#  'deep': 581,
#  'ambiance': 582,
#  'transcendant': 583,
#  'Before': 584,
#  'supposed': 585,
#  'TV': 586,
#  'Now': 587,
#  'containers': 588,
#  'gold': 589,
#  'roasted': 590,
#  'businesses': 591,
#  'block': 592,
#  'Give': 593,
#  'gotten': 594,
#  'beers': 595,
#  'One': 596,
#  'eat': 597,
#  'means': 598,
#  'both': 599,
#  'eel': 600,
#  'dripping': 601,
#  'tasted': 602,
#  'up': 603,
#  'reasonably': 604,
#  'poorly': 605,
#  'extraordinary': 606,
#  'perfection': 607,
#  'listed': 608,
#  'Same': 609,
#  'patio': 610,
#  'fine': 611,
#  'dude': 612,
#  'come': 613,
#  'service': 614,
#  '30s': 615,
#  'neither': 616,
#  'wide': 617,
#  'warmer': 618,
#  'fear': 619,
#  'overall': 620,
#  '$': 621,
#  'Overpriced': 622,
#  'just': 623,
#  'what': 624,
#  'touched': 625,
#  'Omelets': 626,
#  'Plater': 627,
#  'Only': 628,
#  'to': 629,
#  'slow': 630,
#  'sit-down': 631,
#  'corporation': 632,
#  'disaster': 633,
#  'empty': 634,
#  'unfortunately': 635,
#  'that': 636,
#  'Sunday': 637,
#  'sucker': 638,
#  'bakery': 639,
#  'scallop': 640,
#  'hair': 641,
#  'overwhelmed': 642,
#  'break': 643,
#  'Outstanding': 644,
#  'summer': 645,
#  'kids': 646,
#  'circumstances': 647,
#  'pale': 648,
#  'Honeslty': 649,
#  'inexpensive': 650,
#  'bagels': 651,
#  'count': 652,
#  'underwhelming': 653,
#  'those': 654,
#  'hour': 655,
#  'portions': 656,
#  'pulled': 657,
#  'typical': 658,
#  'Be': 659,
#  'expect': 660,
#  'temp.I': 661,
#  "'ve": 662,
#  'wrapped': 663,
#  'Dog': 664,
#  'unique': 665,
#  'disgusted': 666,
#  'garlic': 667,
#  'Cant': 668,
#  'suffers': 669,
#  'greens': 670,
#  'Point': 671,
#  'right': 672,
#  'much': 673,
#  'word': 674,
#  'vodka': 675,
#  'ordered': 676,
#  'meal': 677,
#  'operation': 678,
#  'shawarrrrrrma': 679,
#  'carbs': 680,
#  'double': 681,
#  'usual': 682,
#  'daughter': 683,
#  'T.': 684,
#  'offered': 685,
#  'concept': 686,
#  'cheese': 687,
#  'Any': 688,
#  'bloodiest': 689,
#  'hella': 690,
#  'since': 691,
#  'miss': 692,
#  'little': 693,
#  'piece': 694,
#  'ravoli': 695,
#  'outshining': 696,
#  'spotty': 697,
#  'summary': 698,
#  'Seafood': 699,
#  'unbelievably': 700,
#  'old': 701,
#  'longer': 702,
#  'Definitely': 703,
#  'dealing': 704,
#  'showed': 705,
#  'waitress': 706,
#  'nice': 707,
#  '....': 708,
#  'fair': 709,
#  'Bar': 710,
#  'ended': 711,
#  'return': 712,
#  'WHAT': 713,
#  'Thus': 714,
#  'uninspired': 715,
#  'over-whelm': 716,
#  '6': 717,
#  'inviting': 718,
#  'Last': 719,
#  'might': 720,
#  'style': 721,
#  'man': 722,
#  'every': 723,
#  'Valley': 724,
#  'behind': 725,
#  'filling': 726,
#  'mains': 727,
#  'thumbs': 728,
#  'speedy': 729,
#  'By': 730,
#  'elsewhere': 731,
#  'THIS': 732,
#  'dollars': 733,
#  'treated': 734,
#  'waited': 735,
#  'white': 736,
#  'Bouchon': 737,
#  'shrimp': 738,
#  'honestly': 739,
#  'joint': 740,
#  '?': 741,
#  'meat': 742,
#  'Avoid': 743,
#  'huevos': 744,
#  'Bland': 745,
#  'prepared': 746,
#  'crust': 747,
#  'Christmas': 748,
#  'Stars': 749,
#  'bread': 750,
#  'imagined': 751,
#  'tartar': 752,
#  'BLAND': 753,
#  'instead': 754,
#  'occasional': 755,
#  'Always': 756,
#  'deliciously': 757,
#  'seated': 758,
#  'Caballero': 759,
#  'sides': 760,
#  'anymore': 761,
#  'cavier': 762,
#  'RUDE': 763,
#  'potatoes': 764,
#  '(': 765,
#  'coffee': 766,
#  'hottest': 767,
#  'judge': 768,
#  'meats': 769,
#  'incredible': 770,
#  'chickens': 771,
#  'petrified': 772,
#  'biggest': 773,
#  'bit': 774,
#  'outrageously': 775,
#  'something': 776,
#  'Veggitarian': 777,
#  'trips': 778,
#  'years': 779,
#  'oysters': 780,
#  'trip': 781,
#  'favorite': 782,
#  'grandmother': 783,
#  'room': 784,
#  'managed': 785,
#  'latte': 786,
#  'being': 787,
#  'middle': 788,
#  'Come': 789,
#  'nicest': 790,
#  'please': 791,
#  'steak': 792,
#  'vain': 793,
#  'Unfortunately': 794,
#  'ohhh': 795,
#  'MANY': 796,
#  'cold': 797,
#  'closed': 798,
#  'talk': 799,
#  'turkey': 800,
#  'tomato': 801,
#  'We': 802,
#  'neat': 803,
#  'entrees': 804,
#  'started': 805,
#  'somethat': 806,
#  '40min': 807,
#  'past': 808,
#  'forever': 809,
#  'tough': 810,
#  'dish': 811,
#  'Perhaps': 812,
#  'low': 813,
#  'worker': 814,
#  'should': 815,
#  'How': 816,
#  'says': 817,
#  'Up': 818,
#  'Nothing': 819,
#  'ice': 820,
#  'Steak': 821,
#  'value': 822,
#  'rarely': 823,
#  'review': 824,
#  'medium': 825,
#  'bartenders': 826,
#  'today': 827,
#  'songs': 828,
#  'venue': 829,
#  'tops': 830,
#  'ever': 831,
#  'dressing': 832,
#  'OWNERS': 833,
#  'colder': 834,
#  'lost': 835,
#  'cranberry': 836,
#  'relaxed': 837,
#  'single': 838,
#  'appetizer': 839,
#  'consistent': 840,
#  'provides': 841,
#  'thrilled': 842,
#  'Eve': 843,
#  'leftover': 844,
#  'sergeant': 845,
#  'nigiri': 846,
#  'concern': 847,
#  '1.5lb': 848,
#  '1979': 849,
#  'peach': 850,
#  'hoping': 851,
#  'styrofoam': 852,
#  'packed': 853,
#  'orders': 854,
#  'prefer': 855,
#  'over-priced': 856,
#  'spaghetti': 857,
#  'asking': 858,
#  'house': 859,
#  'company': 860,
#  'happened': 861,
#  'seafood': 862,
#  'attitudes': 863,
#  'stir': 864,
#  'welcome': 865,
#  'truly': 866,
#  'servers': 867,
#  'considering': 868,
#  'bring': 869,
#  'five': 870,
#  'wings': 871,
#  'otherwise': 872,
#  'perfectly': 873,
#  'lacked': 874,
#  'red': 875,
#  'Mandalay': 876,
#  'untoasted': 877,
#  'PERFECT': 878,
#  'batch': 879,
#  'menu': 880,
#  'mile': 881,
#  'moz': 882,
#  'legit': 883,
#  'Cibo': 884,
#  'extra': 885,
#  'seriously': 886,
#  'sad': 887,
#  'going': 888,
#  'insulted': 889,
#  'Buldogis': 890,
#  'INCONSIDERATE': 891,
#  'avocado': 892,
#  'Panna': 893,
#  'their': 894,
#  '-Drinks': 895,
#  'companions': 896,
#  'send': 897,
#  'GO': 898,
#  'tiramisu': 899,
#  'boring': 900,
#  'sample': 901,
#  'guy': 902,
#  'menus': 903,
#  'texture': 904,
#  'Disappointing': 905,
#  'salad': 906,
#  'very': 907,
#  'in-house': 908,
#  '..': 909,
#  'looked': 910,
#  'Han': 911,
#  'book': 912,
#  'calligraphy': 913,
#  'Casino': 914,
#  'expensive': 915,
#  'moist': 916,
#  'gristle': 917,
#  'reading': 918,
#  'way': 919,
#  'sub-par': 920,
#  'awkwardly': 921,
#  'gets': 922,
#  'quality': 923,
#  'walked': 924,
#  'meet': 925,
#  'especially': 926,
#  'fun': 927,
#  'prompt': 928,
#  'after': 929,
#  'Elk': 930,
#  'rushed': 931,
#  'wasted': 932,
#  'priced': 933,
#  'Las': 934,
#  'was': 935,
#  'Macarons': 936,
#  'if': 937,
#  'ten': 938,
#  'low-key': 939,
#  'clean': 940,
#  'chow': 941,
#  'relationship': 942,
#  'M': 943,
#  'non-fancy': 944,
#  'Dos': 945,
#  'unwrapped': 946,
#  'help': 947,
#  'liking': 948,
#  'handed': 949,
#  'hospitality': 950,
#  'job': 951,
#  'subpar': 952,
#  'round': 953,
#  'went': 954,
#  'Crust': 955,
#  'special': 956,
#  'madhouse': 957,
#  'freaking': 958,
#  'ingredients': 959,
#  'dispenser': 960,
#  'Just': 961,
#  'give': 962,
#  'Sun': 963,
#  'below': 964,
#  'doughy': 965,
#  'groups': 966,
#  'melted': 967,
#  'fact': 968,
#  'said': 969,
#  'cook': 970,
#  'located': 971,
#  'some': 972,
#  'As': 973,
#  'It': 974,
#  'finish': 975,
#  'Soups': 976,
#  'hungry': 977,
#  'pita': 978,
#  'disappointed': 979,
#  'char': 980,
#  'Update': 981,
#  'RI': 982,
#  'needed': 983,
#  'checked': 984,
#  'WEAK': 985,
#  'stay': 986,
#  'our': 987,
#  'bamboo': 988,
#  'year': 989,
#  'price': 990,
#  'group': 991,
#  'menu/': 992,
#  'Yama': 993,
#  'few': 994,
#  'joy': 995,
#  'Noca': 996,
#  'crisp': 997,
#  'sauces': 998,
#  'ladies': 999,
#  ...}

# %%
word_index
# Out:
# {'serivce': 0,
#  'mussels': 1,
#  'sweet': 2,
#  'fan': 3,
#  'grilled': 4,
#  'couple': 5,
#  'heat': 6,
#  'charged': 7,
#  "ya'all": 8,
#  'ago': 9,
#  'Good': 10,
#  'care': 11,
#  'sandwiches': 12,
#  'world': 13,
#  'mostly': 14,
#  'worries': 15,
#  'Your': 16,
#  'veal': 17,
#  'close': 18,
#  'charge': 19,
#  'frustrated': 20,
#  'Philadelphia': 21,
#  'Mmmm': 22,
#  'light': 23,
#  'soup': 24,
#  'else': 25,
#  'personally': 26,
#  'least': 27,
#  'hostess': 28,
#  'Despite': 29,
#  "'s": 30,
#  'profound': 31,
#  'Ryan': 32,
#  'wagyu': 33,
#  'Weird': 34,
#  'serve': 35,
#  'at': 36,
#  'lovely': 37,
#  'Although': 38,
#  'forty': 39,
#  'truffle': 40,
#  'fav': 41,
#  'atrocious': 42,
#  'glass': 43,
#  'twice': 44,
#  'delish': 45,
#  'craving': 46,
#  'fried': 47,
#  'brick': 48,
#  'register': 49,
#  'doing': 50,
#  'sushi': 51,
#  'felt': 52,
#  'theft': 53,
#  'worth': 54,
#  'honest': 55,
#  'sugary': 56,
#  'strangers': 57,
#  'been': 58,
#  'suck': 59,
#  'changing': 60,
#  'pats': 61,
#  'decide': 62,
#  'color': 63,
#  'metro': 64,
#  'Tucson': 65,
#  'hardest': 66,
#  'decorated': 67,
#  'spinach': 68,
#  'Burger': 69,
#  'with': 70,
#  'wildly': 71,
#  'drenched': 72,
#  'reviewing': 73,
#  'places': 74,
#  'Must': 75,
#  'flavourful': 76,
#  'topic': 77,
#  'gyro': 78,
#  'chefs': 79,
#  'happy': 80,
#  ':': 81,
#  'pizza': 82,
#  'jewel': 83,
#  'tasty': 84,
#  'disgust': 85,
#  'NO': 86,
#  'say': 87,
#  'Gordon': 88,
#  'beautiful': 89,
#  'tacos': 90,
#  'My': 91,
#  'Kind': 92,
#  'funny': 93,
#  'dessert': 94,
#  'missed': 95,
#  'ourselves': 96,
#  'thick': 97,
#  'readers': 98,
#  'Sadly': 99,
#  'manager': 100,
#  'tea': 101,
#  'sugar': 102,
#  'head': 103,
#  'Fantastic': 104,
#  'parents': 105,
#  'quit': 106,
#  'further': 107,
#  'Gold': 108,
#  'bites': 109,
#  'vegetables': 110,
#  'slaw': 111,
#  'stepped': 112,
#  'spicier': 113,
#  'bellies': 114,
#  'accident': 115,
#  'though': 116,
#  'giving': 117,
#  'vomited': 118,
#  'smooth': 119,
#  'Probably': 120,
#  'Tasty': 121,
#  'Perfect': 122,
#  'approval': 123,
#  'batter': 124,
#  'fat': 125,
#  'life': 126,
#  'attached': 127,
#  'exceptional': 128,
#  'Why': 129,
#  'worst': 130,
#  'crepe': 131,
#  'seems': 132,
#  'Gyros': 133,
#  'done': 134,
#  'correction': 135,
#  'Ha': 136,
#  'cheated': 137,
#  'holiday': 138,
#  'arrives': 139,
#  'delivery': 140,
#  'Chipotle': 141,
#  'describing': 142,
#  'These': 143,
#  'occasions': 144,
#  'gloves.Everything': 145,
#  'flirting': 146,
#  'unwelcome': 147,
#  "'m": 148,
#  'wave': 149,
#  'dreamed': 150,
#  'prime': 151,
#  'Mushroom': 152,
#  'indicate': 153,
#  'Bisque': 154,
#  'large': 155,
#  'calamari': 156,
#  'polite': 157,
#  'promise': 158,
#  'reasonable': 159,
#  'Food': 160,
#  'actual': 161,
#  'exactly': 162,
#  'caterpillar': 163,
#  'eyed': 164,
#  'beauty': 165,
#  'feel': 166,
#  'be': 167,
#  'rice': 168,
#  'similar': 169,
#  '4.00': 170,
#  'she': 171,
#  'Chinese': 172,
#  'OMG': 173,
#  'outta': 174,
#  '.': 175,
#  'visited': 176,
#  'known': 177,
#  'plain': 178,
#  'Jenni': 179,
#  'Aria': 180,
#  'yummy': 181,
#  'no': 182,
#  'or': 183,
#  'bye': 184,
#  'Hunan': 185,
#  'tastings': 186,
#  'about': 187,
#  '90': 188,
#  'during': 189,
#  'caring': 190,
#  'ahead': 191,
#  'She': 192,
#  'returned': 193,
#  'combo': 194,
#  'horrible': 195,
#  'effort': 196,
#  'Furthermore': 197,
#  'above': 198,
#  'workers': 199,
#  'plantains': 200,
#  'arepas': 201,
#  'platter': 202,
#  'number': 203,
#  'myself': 204,
#  'patty': 205,
#  'Those': 206,
#  'vinaigrette': 207,
#  'AN': 208,
#  'rib': 209,
#  'Owner': 210,
#  'recently': 211,
#  'charcoal': 212,
#  'juice': 213,
#  'tummy': 214,
#  'fluffy': 215,
#  'swung': 216,
#  'returning': 217,
#  'Great': 218,
#  'order': 219,
#  'strip': 220,
#  'experience': 221,
#  'puree': 222,
#  'missing': 223,
#  'Pho': 224,
#  'Do': 225,
#  'will': 226,
#  'ALL': 227,
#  'APPETIZERS': 228,
#  'sound': 229,
#  'Scottsdale': 230,
#  'business': 231,
#  'solid': 232,
#  'papers': 233,
#  'Francisco': 234,
#  'creamy': 235,
#  'Standard': 236,
#  'doubt': 237,
#  'grill': 238,
#  'Customer': 239,
#  'Much': 240,
#  'without': 241,
#  'spices': 242,
#  'wrap': 243,
#  'nasty': 244,
#  'lovers': 245,
#  'dog': 246,
#  'Really': 247,
#  'accomodate': 248,
#  'tender': 249,
#  'original': 250,
#  'pace': 251,
#  'replenished': 252,
#  '3/4ths': 253,
#  'Chicken': 254,
#  'Third': 255,
#  'would': 256,
#  'definately': 257,
#  'cover': 258,
#  'always': 259,
#  '%': 260,
#  'Mary': 261,
#  'front': 262,
#  'want': 263,
#  'Are': 264,
#  'arrived': 265,
#  'lettuce': 266,
#  'together': 267,
#  'not': 268,
#  'crazy': 269,
#  'suggestions': 270,
#  'genuinely': 271,
#  'relleno': 272,
#  'chipolte': 273,
#  'MUST': 274,
#  'read': 275,
#  'somewhat': 276,
#  'girlfriend': 277,
#  'memory': 278,
#  'have': 279,
#  'soundtrack': 280,
#  'cakes': 281,
#  'cute': 282,
#  'asked': 283,
#  'Thumbs': 284,
#  'oil': 285,
#  'pretty': 286,
#  'Steve': 287,
#  'most': 288,
#  'Anyway': 289,
#  'treat': 290,
#  'After': 291,
#  'are': 292,
#  'inspired': 293,
#  'itself': 294,
#  'Pizza': 295,
#  '``': 296,
#  'dining': 297,
#  'Attack': 298,
#  'eaten': 299,
#  'down': 300,
#  'glance': 301,
#  'driving': 302,
#  'haunt': 303,
#  'dirty-': 304,
#  'grossed': 305,
#  'pears': 306,
#  'Nan': 307,
#  'satisfying': 308,
#  'Hopefully': 309,
#  'curry': 310,
#  'final': 311,
#  'ways': 312,
#  'Pineapple': 313,
#  'know': 314,
#  'famous': 315,
#  'lawyers': 316,
#  'Wow': 317,
#  'so': 318,
#  'Area': 319,
#  'do': 320,
#  'charming': 321,
#  'dedicated': 322,
#  'use': 323,
#  'sat': 324,
#  'fireball': 325,
#  'NOW': 326,
#  'nut': 327,
#  'fish': 328,
#  'professional': 329,
#  'poisoning': 330,
#  'Favorite': 331,
#  'than': 332,
#  'mozzarella': 333,
#  'imagine': 334,
#  'sitting': 335,
#  'AVOID': 336,
#  'In': 337,
#  'screwed': 338,
#  'UNREAL': 339,
#  'bucks': 340,
#  'whatsoever': 341,
#  'him': 342,
#  'quantity': 343,
#  'we': 344,
#  'last': 345,
#  'taco': 346,
#  'Paradise': 347,
#  'Disappointed': 348,
#  'FORWARD': 349,
#  'dirty': 350,
#  'fillet': 351,
#  'angry': 352,
#  'refried': 353,
#  'Eggplant': 354,
#  'muffin': 355,
#  'rge': 356,
#  'friendly': 357,
#  'still': 358,
#  'box': 359,
#  'nay': 360,
#  'starving': 361,
#  'appealing': 362,
#  'he': 363,
#  'EXPERIENCE': 364,
#  'pancakes': 365,
#  'par': 366,
#  'dirt': 367,
#  'besides': 368,
#  'fill': 369,
#  'they': 370,
#  'waitresses': 371,
#  'Cotta': 372,
#  'Google': 373,
#  'working/eating': 374,
#  'overhaul': 375,
#  'fucking': 376,
#  'chai': 377,
#  'basically': 378,
#  'Greek': 379,
#  'Dessert': 380,
#  'boys': 381,
#  'Tigerlilly': 382,
#  'mood': 383,
#  'crab': 384,
#  'used': 385,
#  'downside': 386,
#  'ratio': 387,
#  'fast': 388,
#  'gave': 389,
#  'insanely': 390,
#  'correct': 391,
#  'server': 392,
#  'almonds': 393,
#  'location': 394,
#  'sever': 395,
#  'Breeze': 396,
#  'NYC': 397,
#  'short': 398,
#  'constructed': 399,
#  'chip': 400,
#  'take': 401,
#  'Would': 402,
#  'flavor': 403,
#  'Everything': 404,
#  'duck': 405,
#  'building': 406,
#  'Crema': 407,
#  'spends': 408,
#  'Best': 409,
#  'greeted': 410,
#  'Del': 411,
#  'smelled': 412,
#  'getting': 413,
#  'how': 414,
#  'Firehouse': 415,
#  'Delicious': 416,
#  'exceeding': 417,
#  'towards': 418,
#  'couples': 419,
#  'pine': 420,
#  'mistake': 421,
#  'connoisseur': 422,
#  'spicy': 423,
#  'BEST': 424,
#  'What': 425,
#  'raspberry': 426,
#  'Hell': 427,
#  'tap': 428,
#  'wait': 429,
#  'covered': 430,
#  'smoothies': 431,
#  'Boy': 432,
#  'BITCHES': 433,
#  'her': 434,
#  'gratuity': 435,
#  'ethic': 436,
#  'onion': 437,
#  'FLAVOR': 438,
#  'cake': 439,
#  'portion': 440,
#  'regularly': 441,
#  'hooked': 442,
#  'caught': 443,
#  'flavorless': 444,
#  'coconut': 445,
#  'Jeff': 446,
#  'airport': 447,
#  'thought': 448,
#  'mein': 449,
#  '8': 450,
#  'callings': 451,
#  '*': 452,
#  'Ninja': 453,
#  'black': 454,
#  'due': 455,
#  'lukewarm': 456,
#  'boxes': 457,
#  'huge': 458,
#  'pleasure': 459,
#  'obviously': 460,
#  'drag': 461,
#  'elegantly': 462,
#  'Shrimp-': 463,
#  'average': 464,
#  'banana': 465,
#  'star': 466,
#  'ala': 467,
#  'turn': 468,
#  'boyfriend': 469,
#  'THE': 470,
#  'falling': 471,
#  'pastry': 472,
#  'struggle': 473,
#  'biscuits': 474,
#  'apologize': 475,
#  'guacamole': 476,
#  'SHOULD': 477,
#  'rave': 478,
#  'cost': 479,
#  'barely': 480,
#  'family': 481,
#  'fail': 482,
#  'owned': 483,
#  'Host': 484,
#  'Bellagio': 485,
#  'bowl': 486,
#  'cream': 487,
#  'Of': 488,
#  'Mediocre': 489,
#  'hilarious': 490,
#  'profiterole': 491,
#  '40': 492,
#  '1': 493,
#  'fabulous': 494,
#  'cafe': 495,
#  'thinking': 496,
#  'TOLD': 497,
#  'enjoyable': 498,
#  'terrible': 499,
#  'restaurant': 500,
#  'sign': 501,
#  'drastically': 502,
#  'petty': 503,
#  'gone': 504,
#  'weekend': 505,
#  'end': 506,
#  'selection': 507,
#  'in': 508,
#  'pack': 509,
#  'spot': 510,
#  'allergy': 511,
#  'winner': 512,
#  'crawfish': 513,
#  'lightly': 514,
#  'find': 515,
#  'Heart': 516,
#  'Penne': 517,
#  'Caesar': 518,
#  'mixed': 519,
#  'writing': 520,
#  'older': 521,
#  'crêpe': 522,
#  'enthusiastic': 523,
#  'vanilla': 524,
#  'pissd': 525,
#  'killer': 526,
#  'hard': 527,
#  'apology': 528,
#  'ordering': 529,
#  'loved': 530,
#  'on': 531,
#  'shopping': 532,
#  'helped': 533,
#  'pancake': 534,
#  'particular': 535,
#  'gluten': 536,
#  'dry': 537,
#  'goat': 538,
#  'unhealthy': 539,
#  'ignore': 540,
#  'can': 541,
#  'top': 542,
#  'apart': 543,
#  'hand': 544,
#  'over': 545,
#  'pleasant': 546,
#  'Grill': 547,
#  'opinion': 548,
#  'However': 549,
#  'Tasted': 550,
#  'sauce': 551,
#  'pastas': 552,
#  'kiddos': 553,
#  'Mom': 554,
#  'juries': 555,
#  '--': 556,
#  'pepper': 557,
#  'mushrooms': 558,
#  '&': 559,
#  'healthy': 560,
#  'Check': 561,
#  'yellow': 562,
#  'lots': 563,
#  'unbelievable': 564,
#  'mom': 565,
#  'signs': 566,
#  'realized': 567,
#  'of': 568,
#  'ribeye': 569,
#  'figured': 570,
#  'offers': 571,
#  'BARGAIN': 572,
#  'witnessed': 573,
#  'sticks': 574,
#  'patron': 575,
#  'extensive': 576,
#  '23': 577,
#  'baby': 578,
#  'added': 579,
#  'Filet': 580,
#  'deep': 581,
#  'ambiance': 582,
#  'transcendant': 583,
#  'Before': 584,
#  'supposed': 585,
#  'TV': 586,
#  'Now': 587,
#  'containers': 588,
#  'gold': 589,
#  'roasted': 590,
#  'businesses': 591,
#  'block': 592,
#  'Give': 593,
#  'gotten': 594,
#  'beers': 595,
#  'One': 596,
#  'eat': 597,
#  'means': 598,
#  'both': 599,
#  'eel': 600,
#  'dripping': 601,
#  'tasted': 602,
#  'up': 603,
#  'reasonably': 604,
#  'poorly': 605,
#  'extraordinary': 606,
#  'perfection': 607,
#  'listed': 608,
#  'Same': 609,
#  'patio': 610,
#  'fine': 611,
#  'dude': 612,
#  'come': 613,
#  'service': 614,
#  '30s': 615,
#  'neither': 616,
#  'wide': 617,
#  'warmer': 618,
#  'fear': 619,
#  'overall': 620,
#  '$': 621,
#  'Overpriced': 622,
#  'just': 623,
#  'what': 624,
#  'touched': 625,
#  'Omelets': 626,
#  'Plater': 627,
#  'Only': 628,
#  'to': 629,
#  'slow': 630,
#  'sit-down': 631,
#  'corporation': 632,
#  'disaster': 633,
#  'empty': 634,
#  'unfortunately': 635,
#  'that': 636,
#  'Sunday': 637,
#  'sucker': 638,
#  'bakery': 639,
#  'scallop': 640,
#  'hair': 641,
#  'overwhelmed': 642,
#  'break': 643,
#  'Outstanding': 644,
#  'summer': 645,
#  'kids': 646,
#  'circumstances': 647,
#  'pale': 648,
#  'Honeslty': 649,
#  'inexpensive': 650,
#  'bagels': 651,
#  'count': 652,
#  'underwhelming': 653,
#  'those': 654,
#  'hour': 655,
#  'portions': 656,
#  'pulled': 657,
#  'typical': 658,
#  'Be': 659,
#  'expect': 660,
#  'temp.I': 661,
#  "'ve": 662,
#  'wrapped': 663,
#  'Dog': 664,
#  'unique': 665,
#  'disgusted': 666,
#  'garlic': 667,
#  'Cant': 668,
#  'suffers': 669,
#  'greens': 670,
#  'Point': 671,
#  'right': 672,
#  'much': 673,
#  'word': 674,
#  'vodka': 675,
#  'ordered': 676,
#  'meal': 677,
#  'operation': 678,
#  'shawarrrrrrma': 679,
#  'carbs': 680,
#  'double': 681,
#  'usual': 682,
#  'daughter': 683,
#  'T.': 684,
#  'offered': 685,
#  'concept': 686,
#  'cheese': 687,
#  'Any': 688,
#  'bloodiest': 689,
#  'hella': 690,
#  'since': 691,
#  'miss': 692,
#  'little': 693,
#  'piece': 694,
#  'ravoli': 695,
#  'outshining': 696,
#  'spotty': 697,
#  'summary': 698,
#  'Seafood': 699,
#  'unbelievably': 700,
#  'old': 701,
#  'longer': 702,
#  'Definitely': 703,
#  'dealing': 704,
#  'showed': 705,
#  'waitress': 706,
#  'nice': 707,
#  '....': 708,
#  'fair': 709,
#  'Bar': 710,
#  'ended': 711,
#  'return': 712,
#  'WHAT': 713,
#  'Thus': 714,
#  'uninspired': 715,
#  'over-whelm': 716,
#  '6': 717,
#  'inviting': 718,
#  'Last': 719,
#  'might': 720,
#  'style': 721,
#  'man': 722,
#  'every': 723,
#  'Valley': 724,
#  'behind': 725,
#  'filling': 726,
#  'mains': 727,
#  'thumbs': 728,
#  'speedy': 729,
#  'By': 730,
#  'elsewhere': 731,
#  'THIS': 732,
#  'dollars': 733,
#  'treated': 734,
#  'waited': 735,
#  'white': 736,
#  'Bouchon': 737,
#  'shrimp': 738,
#  'honestly': 739,
#  'joint': 740,
#  '?': 741,
#  'meat': 742,
#  'Avoid': 743,
#  'huevos': 744,
#  'Bland': 745,
#  'prepared': 746,
#  'crust': 747,
#  'Christmas': 748,
#  'Stars': 749,
#  'bread': 750,
#  'imagined': 751,
#  'tartar': 752,
#  'BLAND': 753,
#  'instead': 754,
#  'occasional': 755,
#  'Always': 756,
#  'deliciously': 757,
#  'seated': 758,
#  'Caballero': 759,
#  'sides': 760,
#  'anymore': 761,
#  'cavier': 762,
#  'RUDE': 763,
#  'potatoes': 764,
#  '(': 765,
#  'coffee': 766,
#  'hottest': 767,
#  'judge': 768,
#  'meats': 769,
#  'incredible': 770,
#  'chickens': 771,
#  'petrified': 772,
#  'biggest': 773,
#  'bit': 774,
#  'outrageously': 775,
#  'something': 776,
#  'Veggitarian': 777,
#  'trips': 778,
#  'years': 779,
#  'oysters': 780,
#  'trip': 781,
#  'favorite': 782,
#  'grandmother': 783,
#  'room': 784,
#  'managed': 785,
#  'latte': 786,
#  'being': 787,
#  'middle': 788,
#  'Come': 789,
#  'nicest': 790,
#  'please': 791,
#  'steak': 792,
#  'vain': 793,
#  'Unfortunately': 794,
#  'ohhh': 795,
#  'MANY': 796,
#  'cold': 797,
#  'closed': 798,
#  'talk': 799,
#  'turkey': 800,
#  'tomato': 801,
#  'We': 802,
#  'neat': 803,
#  'entrees': 804,
#  'started': 805,
#  'somethat': 806,
#  '40min': 807,
#  'past': 808,
#  'forever': 809,
#  'tough': 810,
#  'dish': 811,
#  'Perhaps': 812,
#  'low': 813,
#  'worker': 814,
#  'should': 815,
#  'How': 816,
#  'says': 817,
#  'Up': 818,
#  'Nothing': 819,
#  'ice': 820,
#  'Steak': 821,
#  'value': 822,
#  'rarely': 823,
#  'review': 824,
#  'medium': 825,
#  'bartenders': 826,
#  'today': 827,
#  'songs': 828,
#  'venue': 829,
#  'tops': 830,
#  'ever': 831,
#  'dressing': 832,
#  'OWNERS': 833,
#  'colder': 834,
#  'lost': 835,
#  'cranberry': 836,
#  'relaxed': 837,
#  'single': 838,
#  'appetizer': 839,
#  'consistent': 840,
#  'provides': 841,
#  'thrilled': 842,
#  'Eve': 843,
#  'leftover': 844,
#  'sergeant': 845,
#  'nigiri': 846,
#  'concern': 847,
#  '1.5lb': 848,
#  '1979': 849,
#  'peach': 850,
#  'hoping': 851,
#  'styrofoam': 852,
#  'packed': 853,
#  'orders': 854,
#  'prefer': 855,
#  'over-priced': 856,
#  'spaghetti': 857,
#  'asking': 858,
#  'house': 859,
#  'company': 860,
#  'happened': 861,
#  'seafood': 862,
#  'attitudes': 863,
#  'stir': 864,
#  'welcome': 865,
#  'truly': 866,
#  'servers': 867,
#  'considering': 868,
#  'bring': 869,
#  'five': 870,
#  'wings': 871,
#  'otherwise': 872,
#  'perfectly': 873,
#  'lacked': 874,
#  'red': 875,
#  'Mandalay': 876,
#  'untoasted': 877,
#  'PERFECT': 878,
#  'batch': 879,
#  'menu': 880,
#  'mile': 881,
#  'moz': 882,
#  'legit': 883,
#  'Cibo': 884,
#  'extra': 885,
#  'seriously': 886,
#  'sad': 887,
#  'going': 888,
#  'insulted': 889,
#  'Buldogis': 890,
#  'INCONSIDERATE': 891,
#  'avocado': 892,
#  'Panna': 893,
#  'their': 894,
#  '-Drinks': 895,
#  'companions': 896,
#  'send': 897,
#  'GO': 898,
#  'tiramisu': 899,
#  'boring': 900,
#  'sample': 901,
#  'guy': 902,
#  'menus': 903,
#  'texture': 904,
#  'Disappointing': 905,
#  'salad': 906,
#  'very': 907,
#  'in-house': 908,
#  '..': 909,
#  'looked': 910,
#  'Han': 911,
#  'book': 912,
#  'calligraphy': 913,
#  'Casino': 914,
#  'expensive': 915,
#  'moist': 916,
#  'gristle': 917,
#  'reading': 918,
#  'way': 919,
#  'sub-par': 920,
#  'awkwardly': 921,
#  'gets': 922,
#  'quality': 923,
#  'walked': 924,
#  'meet': 925,
#  'especially': 926,
#  'fun': 927,
#  'prompt': 928,
#  'after': 929,
#  'Elk': 930,
#  'rushed': 931,
#  'wasted': 932,
#  'priced': 933,
#  'Las': 934,
#  'was': 935,
#  'Macarons': 936,
#  'if': 937,
#  'ten': 938,
#  'low-key': 939,
#  'clean': 940,
#  'chow': 941,
#  'relationship': 942,
#  'M': 943,
#  'non-fancy': 944,
#  'Dos': 945,
#  'unwrapped': 946,
#  'help': 947,
#  'liking': 948,
#  'handed': 949,
#  'hospitality': 950,
#  'job': 951,
#  'subpar': 952,
#  'round': 953,
#  'went': 954,
#  'Crust': 955,
#  'special': 956,
#  'madhouse': 957,
#  'freaking': 958,
#  'ingredients': 959,
#  'dispenser': 960,
#  'Just': 961,
#  'give': 962,
#  'Sun': 963,
#  'below': 964,
#  'doughy': 965,
#  'groups': 966,
#  'melted': 967,
#  'fact': 968,
#  'said': 969,
#  'cook': 970,
#  'located': 971,
#  'some': 972,
#  'As': 973,
#  'It': 974,
#  'finish': 975,
#  'Soups': 976,
#  'hungry': 977,
#  'pita': 978,
#  'disappointed': 979,
#  'char': 980,
#  'Update': 981,
#  'RI': 982,
#  'needed': 983,
#  'checked': 984,
#  'WEAK': 985,
#  'stay': 986,
#  'our': 987,
#  'bamboo': 988,
#  'year': 989,
#  'price': 990,
#  'group': 991,
#  'menu/': 992,
#  'Yama': 993,
#  'few': 994,
#  'joy': 995,
#  'Noca': 996,
#  'crisp': 997,
#  'sauces': 998,
#  'ladies': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'serivce',
#  1: 'mussels',
#  2: 'sweet',
#  3: 'fan',
#  4: 'grilled',
#  5: 'couple',
#  6: 'heat',
#  7: 'charged',
#  8: "ya'all",
#  9: 'ago',
#  10: 'Good',
#  11: 'care',
#  12: 'sandwiches',
#  13: 'world',
#  14: 'mostly',
#  15: 'worries',
#  16: 'Your',
#  17: 'veal',
#  18: 'close',
#  19: 'charge',
#  20: 'frustrated',
#  21: 'Philadelphia',
#  22: 'Mmmm',
#  23: 'light',
#  24: 'soup',
#  25: 'else',
#  26: 'personally',
#  27: 'least',
#  28: 'hostess',
#  29: 'Despite',
#  30: "'s",
#  31: 'profound',
#  32: 'Ryan',
#  33: 'wagyu',
#  34: 'Weird',
#  35: 'serve',
#  36: 'at',
#  37: 'lovely',
#  38: 'Although',
#  39: 'forty',
#  40: 'truffle',
#  41: 'fav',
#  42: 'atrocious',
#  43: 'glass',
#  44: 'twice',
#  45: 'delish',
#  46: 'craving',
#  47: 'fried',
#  48: 'brick',
#  49: 'register',
#  50: 'doing',
#  51: 'sushi',
#  52: 'felt',
#  53: 'theft',
#  54: 'worth',
#  55: 'honest',
#  56: 'sugary',
#  57: 'strangers',
#  58: 'been',
#  59: 'suck',
#  60: 'changing',
#  61: 'pats',
#  62: 'decide',
#  63: 'color',
#  64: 'metro',
#  65: 'Tucson',
#  66: 'hardest',
#  67: 'decorated',
#  68: 'spinach',
#  69: 'Burger',
#  70: 'with',
#  71: 'wildly',
#  72: 'drenched',
#  73: 'reviewing',
#  74: 'places',
#  75: 'Must',
#  76: 'flavourful',
#  77: 'topic',
#  78: 'gyro',
#  79: 'chefs',
#  80: 'happy',
#  81: ':',
#  82: 'pizza',
#  83: 'jewel',
#  84: 'tasty',
#  85: 'disgust',
#  86: 'NO',
#  87: 'say',
#  88: 'Gordon',
#  89: 'beautiful',
#  90: 'tacos',
#  91: 'My',
#  92: 'Kind',
#  93: 'funny',
#  94: 'dessert',
#  95: 'missed',
#  96: 'ourselves',
#  97: 'thick',
#  98: 'readers',
#  99: 'Sadly',
#  100: 'manager',
#  101: 'tea',
#  102: 'sugar',
#  103: 'head',
#  104: 'Fantastic',
#  105: 'parents',
#  106: 'quit',
#  107: 'further',
#  108: 'Gold',
#  109: 'bites',
#  110: 'vegetables',
#  111: 'slaw',
#  112: 'stepped',
#  113: 'spicier',
#  114: 'bellies',
#  115: 'accident',
#  116: 'though',
#  117: 'giving',
#  118: 'vomited',
#  119: 'smooth',
#  120: 'Probably',
#  121: 'Tasty',
#  122: 'Perfect',
#  123: 'approval',
#  124: 'batter',
#  125: 'fat',
#  126: 'life',
#  127: 'attached',
#  128: 'exceptional',
#  129: 'Why',
#  130: 'worst',
#  131: 'crepe',
#  132: 'seems',
#  133: 'Gyros',
#  134: 'done',
#  135: 'correction',
#  136: 'Ha',
#  137: 'cheated',
#  138: 'holiday',
#  139: 'arrives',
#  140: 'delivery',
#  141: 'Chipotle',
#  142: 'describing',
#  143: 'These',
#  144: 'occasions',
#  145: 'gloves.Everything',
#  146: 'flirting',
#  147: 'unwelcome',
#  148: "'m",
#  149: 'wave',
#  150: 'dreamed',
#  151: 'prime',
#  152: 'Mushroom',
#  153: 'indicate',
#  154: 'Bisque',
#  155: 'large',
#  156: 'calamari',
#  157: 'polite',
#  158: 'promise',
#  159: 'reasonable',
#  160: 'Food',
#  161: 'actual',
#  162: 'exactly',
#  163: 'caterpillar',
#  164: 'eyed',
#  165: 'beauty',
#  166: 'feel',
#  167: 'be',
#  168: 'rice',
#  169: 'similar',
#  170: '4.00',
#  171: 'she',
#  172: 'Chinese',
#  173: 'OMG',
#  174: 'outta',
#  175: '.',
#  176: 'visited',
#  177: 'known',
#  178: 'plain',
#  179: 'Jenni',
#  180: 'Aria',
#  181: 'yummy',
#  182: 'no',
#  183: 'or',
#  184: 'bye',
#  185: 'Hunan',
#  186: 'tastings',
#  187: 'about',
#  188: '90',
#  189: 'during',
#  190: 'caring',
#  191: 'ahead',
#  192: 'She',
#  193: 'returned',
#  194: 'combo',
#  195: 'horrible',
#  196: 'effort',
#  197: 'Furthermore',
#  198: 'above',
#  199: 'workers',
#  200: 'plantains',
#  201: 'arepas',
#  202: 'platter',
#  203: 'number',
#  204: 'myself',
#  205: 'patty',
#  206: 'Those',
#  207: 'vinaigrette',
#  208: 'AN',
#  209: 'rib',
#  210: 'Owner',
#  211: 'recently',
#  212: 'charcoal',
#  213: 'juice',
#  214: 'tummy',
#  215: 'fluffy',
#  216: 'swung',
#  217: 'returning',
#  218: 'Great',
#  219: 'order',
#  220: 'strip',
#  221: 'experience',
#  222: 'puree',
#  223: 'missing',
#  224: 'Pho',
#  225: 'Do',
#  226: 'will',
#  227: 'ALL',
#  228: 'APPETIZERS',
#  229: 'sound',
#  230: 'Scottsdale',
#  231: 'business',
#  232: 'solid',
#  233: 'papers',
#  234: 'Francisco',
#  235: 'creamy',
#  236: 'Standard',
#  237: 'doubt',
#  238: 'grill',
#  239: 'Customer',
#  240: 'Much',
#  241: 'without',
#  242: 'spices',
#  243: 'wrap',
#  244: 'nasty',
#  245: 'lovers',
#  246: 'dog',
#  247: 'Really',
#  248: 'accomodate',
#  249: 'tender',
#  250: 'original',
#  251: 'pace',
#  252: 'replenished',
#  253: '3/4ths',
#  254: 'Chicken',
#  255: 'Third',
#  256: 'would',
#  257: 'definately',
#  258: 'cover',
#  259: 'always',
#  260: '%',
#  261: 'Mary',
#  262: 'front',
#  263: 'want',
#  264: 'Are',
#  265: 'arrived',
#  266: 'lettuce',
#  267: 'together',
#  268: 'not',
#  269: 'crazy',
#  270: 'suggestions',
#  271: 'genuinely',
#  272: 'relleno',
#  273: 'chipolte',
#  274: 'MUST',
#  275: 'read',
#  276: 'somewhat',
#  277: 'girlfriend',
#  278: 'memory',
#  279: 'have',
#  280: 'soundtrack',
#  281: 'cakes',
#  282: 'cute',
#  283: 'asked',
#  284: 'Thumbs',
#  285: 'oil',
#  286: 'pretty',
#  287: 'Steve',
#  288: 'most',
#  289: 'Anyway',
#  290: 'treat',
#  291: 'After',
#  292: 'are',
#  293: 'inspired',
#  294: 'itself',
#  295: 'Pizza',
#  296: '``',
#  297: 'dining',
#  298: 'Attack',
#  299: 'eaten',
#  300: 'down',
#  301: 'glance',
#  302: 'driving',
#  303: 'haunt',
#  304: 'dirty-',
#  305: 'grossed',
#  306: 'pears',
#  307: 'Nan',
#  308: 'satisfying',
#  309: 'Hopefully',
#  310: 'curry',
#  311: 'final',
#  312: 'ways',
#  313: 'Pineapple',
#  314: 'know',
#  315: 'famous',
#  316: 'lawyers',
#  317: 'Wow',
#  318: 'so',
#  319: 'Area',
#  320: 'do',
#  321: 'charming',
#  322: 'dedicated',
#  323: 'use',
#  324: 'sat',
#  325: 'fireball',
#  326: 'NOW',
#  327: 'nut',
#  328: 'fish',
#  329: 'professional',
#  330: 'poisoning',
#  331: 'Favorite',
#  332: 'than',
#  333: 'mozzarella',
#  334: 'imagine',
#  335: 'sitting',
#  336: 'AVOID',
#  337: 'In',
#  338: 'screwed',
#  339: 'UNREAL',
#  340: 'bucks',
#  341: 'whatsoever',
#  342: 'him',
#  343: 'quantity',
#  344: 'we',
#  345: 'last',
#  346: 'taco',
#  347: 'Paradise',
#  348: 'Disappointed',
#  349: 'FORWARD',
#  350: 'dirty',
#  351: 'fillet',
#  352: 'angry',
#  353: 'refried',
#  354: 'Eggplant',
#  355: 'muffin',
#  356: 'rge',
#  357: 'friendly',
#  358: 'still',
#  359: 'box',
#  360: 'nay',
#  361: 'starving',
#  362: 'appealing',
#  363: 'he',
#  364: 'EXPERIENCE',
#  365: 'pancakes',
#  366: 'par',
#  367: 'dirt',
#  368: 'besides',
#  369: 'fill',
#  370: 'they',
#  371: 'waitresses',
#  372: 'Cotta',
#  373: 'Google',
#  374: 'working/eating',
#  375: 'overhaul',
#  376: 'fucking',
#  377: 'chai',
#  378: 'basically',
#  379: 'Greek',
#  380: 'Dessert',
#  381: 'boys',
#  382: 'Tigerlilly',
#  383: 'mood',
#  384: 'crab',
#  385: 'used',
#  386: 'downside',
#  387: 'ratio',
#  388: 'fast',
#  389: 'gave',
#  390: 'insanely',
#  391: 'correct',
#  392: 'server',
#  393: 'almonds',
#  394: 'location',
#  395: 'sever',
#  396: 'Breeze',
#  397: 'NYC',
#  398: 'short',
#  399: 'constructed',
#  400: 'chip',
#  401: 'take',
#  402: 'Would',
#  403: 'flavor',
#  404: 'Everything',
#  405: 'duck',
#  406: 'building',
#  407: 'Crema',
#  408: 'spends',
#  409: 'Best',
#  410: 'greeted',
#  411: 'Del',
#  412: 'smelled',
#  413: 'getting',
#  414: 'how',
#  415: 'Firehouse',
#  416: 'Delicious',
#  417: 'exceeding',
#  418: 'towards',
#  419: 'couples',
#  420: 'pine',
#  421: 'mistake',
#  422: 'connoisseur',
#  423: 'spicy',
#  424: 'BEST',
#  425: 'What',
#  426: 'raspberry',
#  427: 'Hell',
#  428: 'tap',
#  429: 'wait',
#  430: 'covered',
#  431: 'smoothies',
#  432: 'Boy',
#  433: 'BITCHES',
#  434: 'her',
#  435: 'gratuity',
#  436: 'ethic',
#  437: 'onion',
#  438: 'FLAVOR',
#  439: 'cake',
#  440: 'portion',
#  441: 'regularly',
#  442: 'hooked',
#  443: 'caught',
#  444: 'flavorless',
#  445: 'coconut',
#  446: 'Jeff',
#  447: 'airport',
#  448: 'thought',
#  449: 'mein',
#  450: '8',
#  451: 'callings',
#  452: '*',
#  453: 'Ninja',
#  454: 'black',
#  455: 'due',
#  456: 'lukewarm',
#  457: 'boxes',
#  458: 'huge',
#  459: 'pleasure',
#  460: 'obviously',
#  461: 'drag',
#  462: 'elegantly',
#  463: 'Shrimp-',
#  464: 'average',
#  465: 'banana',
#  466: 'star',
#  467: 'ala',
#  468: 'turn',
#  469: 'boyfriend',
#  470: 'THE',
#  471: 'falling',
#  472: 'pastry',
#  473: 'struggle',
#  474: 'biscuits',
#  475: 'apologize',
#  476: 'guacamole',
#  477: 'SHOULD',
#  478: 'rave',
#  479: 'cost',
#  480: 'barely',
#  481: 'family',
#  482: 'fail',
#  483: 'owned',
#  484: 'Host',
#  485: 'Bellagio',
#  486: 'bowl',
#  487: 'cream',
#  488: 'Of',
#  489: 'Mediocre',
#  490: 'hilarious',
#  491: 'profiterole',
#  492: '40',
#  493: '1',
#  494: 'fabulous',
#  495: 'cafe',
#  496: 'thinking',
#  497: 'TOLD',
#  498: 'enjoyable',
#  499: 'terrible',
#  500: 'restaurant',
#  501: 'sign',
#  502: 'drastically',
#  503: 'petty',
#  504: 'gone',
#  505: 'weekend',
#  506: 'end',
#  507: 'selection',
#  508: 'in',
#  509: 'pack',
#  510: 'spot',
#  511: 'allergy',
#  512: 'winner',
#  513: 'crawfish',
#  514: 'lightly',
#  515: 'find',
#  516: 'Heart',
#  517: 'Penne',
#  518: 'Caesar',
#  519: 'mixed',
#  520: 'writing',
#  521: 'older',
#  522: 'crêpe',
#  523: 'enthusiastic',
#  524: 'vanilla',
#  525: 'pissd',
#  526: 'killer',
#  527: 'hard',
#  528: 'apology',
#  529: 'ordering',
#  530: 'loved',
#  531: 'on',
#  532: 'shopping',
#  533: 'helped',
#  534: 'pancake',
#  535: 'particular',
#  536: 'gluten',
#  537: 'dry',
#  538: 'goat',
#  539: 'unhealthy',
#  540: 'ignore',
#  541: 'can',
#  542: 'top',
#  543: 'apart',
#  544: 'hand',
#  545: 'over',
#  546: 'pleasant',
#  547: 'Grill',
#  548: 'opinion',
#  549: 'However',
#  550: 'Tasted',
#  551: 'sauce',
#  552: 'pastas',
#  553: 'kiddos',
#  554: 'Mom',
#  555: 'juries',
#  556: '--',
#  557: 'pepper',
#  558: 'mushrooms',
#  559: '&',
#  560: 'healthy',
#  561: 'Check',
#  562: 'yellow',
#  563: 'lots',
#  564: 'unbelievable',
#  565: 'mom',
#  566: 'signs',
#  567: 'realized',
#  568: 'of',
#  569: 'ribeye',
#  570: 'figured',
#  571: 'offers',
#  572: 'BARGAIN',
#  573: 'witnessed',
#  574: 'sticks',
#  575: 'patron',
#  576: 'extensive',
#  577: '23',
#  578: 'baby',
#  579: 'added',
#  580: 'Filet',
#  581: 'deep',
#  582: 'ambiance',
#  583: 'transcendant',
#  584: 'Before',
#  585: 'supposed',
#  586: 'TV',
#  587: 'Now',
#  588: 'containers',
#  589: 'gold',
#  590: 'roasted',
#  591: 'businesses',
#  592: 'block',
#  593: 'Give',
#  594: 'gotten',
#  595: 'beers',
#  596: 'One',
#  597: 'eat',
#  598: 'means',
#  599: 'both',
#  600: 'eel',
#  601: 'dripping',
#  602: 'tasted',
#  603: 'up',
#  604: 'reasonably',
#  605: 'poorly',
#  606: 'extraordinary',
#  607: 'perfection',
#  608: 'listed',
#  609: 'Same',
#  610: 'patio',
#  611: 'fine',
#  612: 'dude',
#  613: 'come',
#  614: 'service',
#  615: '30s',
#  616: 'neither',
#  617: 'wide',
#  618: 'warmer',
#  619: 'fear',
#  620: 'overall',
#  621: '$',
#  622: 'Overpriced',
#  623: 'just',
#  624: 'what',
#  625: 'touched',
#  626: 'Omelets',
#  627: 'Plater',
#  628: 'Only',
#  629: 'to',
#  630: 'slow',
#  631: 'sit-down',
#  632: 'corporation',
#  633: 'disaster',
#  634: 'empty',
#  635: 'unfortunately',
#  636: 'that',
#  637: 'Sunday',
#  638: 'sucker',
#  639: 'bakery',
#  640: 'scallop',
#  641: 'hair',
#  642: 'overwhelmed',
#  643: 'break',
#  644: 'Outstanding',
#  645: 'summer',
#  646: 'kids',
#  647: 'circumstances',
#  648: 'pale',
#  649: 'Honeslty',
#  650: 'inexpensive',
#  651: 'bagels',
#  652: 'count',
#  653: 'underwhelming',
#  654: 'those',
#  655: 'hour',
#  656: 'portions',
#  657: 'pulled',
#  658: 'typical',
#  659: 'Be',
#  660: 'expect',
#  661: 'temp.I',
#  662: "'ve",
#  663: 'wrapped',
#  664: 'Dog',
#  665: 'unique',
#  666: 'disgusted',
#  667: 'garlic',
#  668: 'Cant',
#  669: 'suffers',
#  670: 'greens',
#  671: 'Point',
#  672: 'right',
#  673: 'much',
#  674: 'word',
#  675: 'vodka',
#  676: 'ordered',
#  677: 'meal',
#  678: 'operation',
#  679: 'shawarrrrrrma',
#  680: 'carbs',
#  681: 'double',
#  682: 'usual',
#  683: 'daughter',
#  684: 'T.',
#  685: 'offered',
#  686: 'concept',
#  687: 'cheese',
#  688: 'Any',
#  689: 'bloodiest',
#  690: 'hella',
#  691: 'since',
#  692: 'miss',
#  693: 'little',
#  694: 'piece',
#  695: 'ravoli',
#  696: 'outshining',
#  697: 'spotty',
#  698: 'summary',
#  699: 'Seafood',
#  700: 'unbelievably',
#  701: 'old',
#  702: 'longer',
#  703: 'Definitely',
#  704: 'dealing',
#  705: 'showed',
#  706: 'waitress',
#  707: 'nice',
#  708: '....',
#  709: 'fair',
#  710: 'Bar',
#  711: 'ended',
#  712: 'return',
#  713: 'WHAT',
#  714: 'Thus',
#  715: 'uninspired',
#  716: 'over-whelm',
#  717: '6',
#  718: 'inviting',
#  719: 'Last',
#  720: 'might',
#  721: 'style',
#  722: 'man',
#  723: 'every',
#  724: 'Valley',
#  725: 'behind',
#  726: 'filling',
#  727: 'mains',
#  728: 'thumbs',
#  729: 'speedy',
#  730: 'By',
#  731: 'elsewhere',
#  732: 'THIS',
#  733: 'dollars',
#  734: 'treated',
#  735: 'waited',
#  736: 'white',
#  737: 'Bouchon',
#  738: 'shrimp',
#  739: 'honestly',
#  740: 'joint',
#  741: '?',
#  742: 'meat',
#  743: 'Avoid',
#  744: 'huevos',
#  745: 'Bland',
#  746: 'prepared',
#  747: 'crust',
#  748: 'Christmas',
#  749: 'Stars',
#  750: 'bread',
#  751: 'imagined',
#  752: 'tartar',
#  753: 'BLAND',
#  754: 'instead',
#  755: 'occasional',
#  756: 'Always',
#  757: 'deliciously',
#  758: 'seated',
#  759: 'Caballero',
#  760: 'sides',
#  761: 'anymore',
#  762: 'cavier',
#  763: 'RUDE',
#  764: 'potatoes',
#  765: '(',
#  766: 'coffee',
#  767: 'hottest',
#  768: 'judge',
#  769: 'meats',
#  770: 'incredible',
#  771: 'chickens',
#  772: 'petrified',
#  773: 'biggest',
#  774: 'bit',
#  775: 'outrageously',
#  776: 'something',
#  777: 'Veggitarian',
#  778: 'trips',
#  779: 'years',
#  780: 'oysters',
#  781: 'trip',
#  782: 'favorite',
#  783: 'grandmother',
#  784: 'room',
#  785: 'managed',
#  786: 'latte',
#  787: 'being',
#  788: 'middle',
#  789: 'Come',
#  790: 'nicest',
#  791: 'please',
#  792: 'steak',
#  793: 'vain',
#  794: 'Unfortunately',
#  795: 'ohhh',
#  796: 'MANY',
#  797: 'cold',
#  798: 'closed',
#  799: 'talk',
#  800: 'turkey',
#  801: 'tomato',
#  802: 'We',
#  803: 'neat',
#  804: 'entrees',
#  805: 'started',
#  806: 'somethat',
#  807: '40min',
#  808: 'past',
#  809: 'forever',
#  810: 'tough',
#  811: 'dish',
#  812: 'Perhaps',
#  813: 'low',
#  814: 'worker',
#  815: 'should',
#  816: 'How',
#  817: 'says',
#  818: 'Up',
#  819: 'Nothing',
#  820: 'ice',
#  821: 'Steak',
#  822: 'value',
#  823: 'rarely',
#  824: 'review',
#  825: 'medium',
#  826: 'bartenders',
#  827: 'today',
#  828: 'songs',
#  829: 'venue',
#  830: 'tops',
#  831: 'ever',
#  832: 'dressing',
#  833: 'OWNERS',
#  834: 'colder',
#  835: 'lost',
#  836: 'cranberry',
#  837: 'relaxed',
#  838: 'single',
#  839: 'appetizer',
#  840: 'consistent',
#  841: 'provides',
#  842: 'thrilled',
#  843: 'Eve',
#  844: 'leftover',
#  845: 'sergeant',
#  846: 'nigiri',
#  847: 'concern',
#  848: '1.5lb',
#  849: '1979',
#  850: 'peach',
#  851: 'hoping',
#  852: 'styrofoam',
#  853: 'packed',
#  854: 'orders',
#  855: 'prefer',
#  856: 'over-priced',
#  857: 'spaghetti',
#  858: 'asking',
#  859: 'house',
#  860: 'company',
#  861: 'happened',
#  862: 'seafood',
#  863: 'attitudes',
#  864: 'stir',
#  865: 'welcome',
#  866: 'truly',
#  867: 'servers',
#  868: 'considering',
#  869: 'bring',
#  870: 'five',
#  871: 'wings',
#  872: 'otherwise',
#  873: 'perfectly',
#  874: 'lacked',
#  875: 'red',
#  876: 'Mandalay',
#  877: 'untoasted',
#  878: 'PERFECT',
#  879: 'batch',
#  880: 'menu',
#  881: 'mile',
#  882: 'moz',
#  883: 'legit',
#  884: 'Cibo',
#  885: 'extra',
#  886: 'seriously',
#  887: 'sad',
#  888: 'going',
#  889: 'insulted',
#  890: 'Buldogis',
#  891: 'INCONSIDERATE',
#  892: 'avocado',
#  893: 'Panna',
#  894: 'their',
#  895: '-Drinks',
#  896: 'companions',
#  897: 'send',
#  898: 'GO',
#  899: 'tiramisu',
#  900: 'boring',
#  901: 'sample',
#  902: 'guy',
#  903: 'menus',
#  904: 'texture',
#  905: 'Disappointing',
#  906: 'salad',
#  907: 'very',
#  908: 'in-house',
#  909: '..',
#  910: 'looked',
#  911: 'Han',
#  912: 'book',
#  913: 'calligraphy',
#  914: 'Casino',
#  915: 'expensive',
#  916: 'moist',
#  917: 'gristle',
#  918: 'reading',
#  919: 'way',
#  920: 'sub-par',
#  921: 'awkwardly',
#  922: 'gets',
#  923: 'quality',
#  924: 'walked',
#  925: 'meet',
#  926: 'especially',
#  927: 'fun',
#  928: 'prompt',
#  929: 'after',
#  930: 'Elk',
#  931: 'rushed',
#  932: 'wasted',
#  933: 'priced',
#  934: 'Las',
#  935: 'was',
#  936: 'Macarons',
#  937: 'if',
#  938: 'ten',
#  939: 'low-key',
#  940: 'clean',
#  941: 'chow',
#  942: 'relationship',
#  943: 'M',
#  944: 'non-fancy',
#  945: 'Dos',
#  946: 'unwrapped',
#  947: 'help',
#  948: 'liking',
#  949: 'handed',
#  950: 'hospitality',
#  951: 'job',
#  952: 'subpar',
#  953: 'round',
#  954: 'went',
#  955: 'Crust',
#  956: 'special',
#  957: 'madhouse',
#  958: 'freaking',
#  959: 'ingredients',
#  960: 'dispenser',
#  961: 'Just',
#  962: 'give',
#  963: 'Sun',
#  964: 'below',
#  965: 'doughy',
#  966: 'groups',
#  967: 'melted',
#  968: 'fact',
#  969: 'said',
#  970: 'cook',
#  971: 'located',
#  972: 'some',
#  973: 'As',
#  974: 'It',
#  975: 'finish',
#  976: 'Soups',
#  977: 'hungry',
#  978: 'pita',
#  979: 'disappointed',
#  980: 'char',
#  981: 'Update',
#  982: 'RI',
#  983: 'needed',
#  984: 'checked',
#  985: 'WEAK',
#  986: 'stay',
#  987: 'our',
#  988: 'bamboo',
#  989: 'year',
#  990: 'price',
#  991: 'group',
#  992: 'menu/',
#  993: 'Yama',
#  994: 'few',
#  995: 'joy',
#  996: 'Noca',
#  997: 'crisp',
#  998: 'sauces',
#  999: 'ladies',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
            vector[word_index_dic[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
